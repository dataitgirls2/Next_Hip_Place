# %%
import pandas as pd

# %%
df = pd.read_csv('data/201701.csv', encoding='cp949')

# %%
df.head()
# Out:
#    상가건물번호  건물구분        고시일자       법정동코드  특수지코드   번지   호 상가건물블록주소 상가건물동주소  \
# 0   38832     3  2017-01-01  4119011100      0  747  13   부성힐하우스     NaN
# 1   38832     3  2017-01-01  4119011100      0  747  13   부성힐하우스     NaN
# 2   38832     3  2017-01-01  4119011100      0  747  13   부성힐하우스     NaN
# 3   38832     3  2017-01-01  4119011100      0  747  13   부성힐하우스     NaN
# 4   38832     3  2017-01-01  4119011100      0  747  13   부성힐하우스     NaN
#
#    건물층구분코드  상가건물층주소   상가건물호주소  고시가격(원)  전유면적(㎡)  공용면적(㎡)
# 0        4        5  102동504호  1655000    77.12    63.34
# 1        4        6  102동601호  1690000    78.13    64.19
# 2        4        1      103호  4006000    38.00    10.74
# 3        4        1      104호  4006000    43.61    12.29
# 4        4        1      105호  4006000    45.50    12.84

# %%
index = pd.read_csv('data/index.csv', encoding='cp949')

# %%
index
# Out:
#    건물구분코드    내용  특수지코드                 내용.1  건물층구분코드 내용.2
# 0     1.0    상가      0                 일반지번      1.0   지하
# 1     2.0  오피스텔      1                    산      4.0   지상
# 2     3.0  복합건물      2             가,확정예정지번      5.0   옥탑
# 3     NaN   NaN      3  구,확정예정지번(부번이세분화된경우)      NaN  NaN
# 4     NaN   NaN      4                구획정리1      NaN  NaN
# 5     NaN   NaN      5                구획정리2      NaN  NaN
# 6     NaN   NaN      6                   블록      NaN  NaN
# 7     NaN   NaN      7                   구역      NaN  NaN
# 8     NaN   NaN      8                   단지      NaN  NaN
# 9     NaN   NaN      9                  무번지      NaN  NaN

# %%
code = pd.read_csv('data/code.txt', encoding='cp949')

# %%
code.head()
# Out:
#                법정동코드\t법정동명\t폐지여부
# 0          1100000000\t서울특별시\t존재
# 1      1111000000\t서울특별시 종로구\t존재
# 2  1111010100\t서울특별시 종로구 청운동\t존재
# 3  1111010200\t서울특별시 종로구 신교동\t존재
# 4  1111010300\t서울특별시 종로구 궁정동\t존재

# %%
code.columns
# Out:
# Index(['법정동코드\t법정동명\t폐지여부'], dtype='object')

# %%
code = code['법정동코드\t법정동명\t폐지여부'].str.split('\t', expand=True)

# %%
code.head()
# Out:
#             0              1   2
# 0  1100000000          서울특별시  존재
# 1  1111000000      서울특별시 종로구  존재
# 2  1111010100  서울특별시 종로구 청운동  존재
# 3  1111010200  서울특별시 종로구 신교동  존재
# 4  1111010300  서울특별시 종로구 궁정동  존재

# %%
code.columns = ['법정동코드', '법정동명', '폐지여부']

# %%
code.head()
# Out:
#         법정동코드           법정동명 폐지여부
# 0  1100000000          서울특별시   존재
# 1  1111000000      서울특별시 종로구   존재
# 2  1111010100  서울특별시 종로구 청운동   존재
# 3  1111010200  서울특별시 종로구 신교동   존재
# 4  1111010300  서울특별시 종로구 궁정동   존재

# %%
code['폐지여부'].describe()
# Out:
# count     46035
# unique        2
# top          폐지
# freq      25493
# Name: 폐지여부, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1015586 entries, 0 to 1015585
# Data columns (total 15 columns):
# 상가건물번호      1015586 non-null int64
# 건물구분        1015586 non-null int64
# 고시일자        1015586 non-null object
# 법정동코드       1015586 non-null int64
# 특수지코드       1015586 non-null int64
# 번지          1015586 non-null int64
# 호           1015586 non-null int64
# 상가건물블록주소    1015314 non-null object
# 상가건물동주소     980274 non-null object
# 건물층구분코드     1015586 non-null int64
# 상가건물층주소     1015586 non-null int64
# 상가건물호주소     1015583 non-null object
# 고시가격(원)     1015586 non-null int64
# 전유면적(㎡)     1015586 non-null float64
# 공용면적(㎡)     1015586 non-null float64
# dtypes: float64(2), int64(9), object(4)
# memory usage: 116.2+ MB

# %%
code.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46035 entries, 0 to 46034
# Data columns (total 3 columns):
# 법정동코드    46035 non-null object
# 법정동명     46035 non-null object
# 폐지여부     46035 non-null object
# dtypes: object(3)
# memory usage: 1.1+ MB

# %%
code['법정동코드'] = code['법정동코드'].astype(float)

# %%
code.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46035 entries, 0 to 46034
# Data columns (total 3 columns):
# 법정동코드    46035 non-null float64
# 법정동명     46035 non-null object
# 폐지여부     46035 non-null object
# dtypes: float64(1), object(2)
# memory usage: 1.1+ MB

# %%
df['법정동코드'] = df['법정동코드'].astype(float)

# %%
df = df.merge(code, on='법정동코드')

# %%
df = df.loc[df['법정동명'].str.startswith('서울특별시')]

# %%
df.head()
# Out:
#       상가건물번호  건물구분        고시일자         법정동코드  특수지코드   번지  호 상가건물블록주소 상가건물동주소  \
# 2126   38835     3  2017-01-01  1.144010e+09      0  571  0     나눔빌딩   1(단일)
# 2127   38835     3  2017-01-01  1.144010e+09      0  571  0     나눔빌딩   1(단일)
# 2128   38835     3  2017-01-01  1.144010e+09      0  571  0     나눔빌딩   1(단일)
# 2129   38835     3  2017-01-01  1.144010e+09      0  571  0     나눔빌딩   1(단일)
# 2130   38835     3  2017-01-01  1.144010e+09      0  571  0     나눔빌딩   1(단일)
#
#       건물층구분코드  상가건물층주소 상가건물호주소  고시가격(원)  전유면적(㎡)  공용면적(㎡)           법정동명 폐지여부
# 2126        4        1     101  7620000    45.67   41.959  서울특별시 마포구 도화동   존재
# 2127        4        1     102  7620000    37.41   34.370  서울특별시 마포구 도화동   존재
# 2128        4        1     103  7620000    37.41   34.370  서울특별시 마포구 도화동   존재
# 2129        4        1     105  7655000    74.82   68.741  서울특별시 마포구 도화동   존재
# 2130        4        1     106  8496000    42.30   38.863  서울특별시 마포구 도화동   존재

# %%
df['법정동명'].unique()
# Out:
# array(['서울특별시 마포구 도화동', '서울특별시 중구 황학동', '서울특별시 동작구 대방동', '서울특별시 은평구 응암동',
#        '서울특별시 관악구 봉천동', '서울특별시 강서구 화곡동', '서울특별시 종로구 연지동', '서울특별시 관악구 신림동',
#        '서울특별시 구로구 가리봉동', '서울특별시 금천구 독산동', '서울특별시 용산구 원효로3가',
#        '서울특별시 은평구 녹번동', '서울특별시 은평구 역촌동', '서울특별시 양천구 신월동', '서울특별시 은평구 신사동',
#        '서울특별시 송파구 장지동', '서울특별시 도봉구 창동', '서울특별시 중랑구 면목동',
#        '서울특별시 영등포구 영등포동2가', '서울특별시 강북구 번동', '서울특별시 성북구 석관동',
#        '서울특별시 영등포구 당산동4가', '서울특별시 성동구 성수동1가', '서울특별시 송파구 문정동',
#        '서울특별시 영등포구 양평동4가', '서울특별시 강동구 길동', '서울특별시 강동구 강일동',
#        '서울특별시 강동구 천호동', '서울특별시 영등포구 당산동5가', '서울특별시 중랑구 묵동',
#        '서울특별시 서대문구 북가좌동', '서울특별시 동작구 노량진동', '서울특별시 동작구 신대방동',
#        '서울특별시 송파구 거여동', '서울특별시 도봉구 쌍문동', '서울특별시 양천구 목동', '서울특별시 중랑구 신내동',
#        '서울특별시 광진구 화양동', '서울특별시 중구 신당동', '서울특별시 도봉구 방학동', '서울특별시 강서구 등촌동',
#        '서울특별시 영등포구 양평동3가', '서울특별시 은평구 대조동', '서울특별시 은평구 불광동',
#        '서울특별시 송파구 가락동', '서울특별시 구로구 구로동', '서울특별시 영등포구 영등포동1가',
# ...

# %%
df['법정동'] = df['법정동명'].str.split(' ', expand=True)[2]

# %%
df.head()
# Out:
#       상가건물번호  건물구분        고시일자         법정동코드  특수지코드   번지  호 상가건물블록주소 상가건물동주소  \
# 2126   38835     3  2017-01-01  1.144010e+09      0  571  0     나눔빌딩   1(단일)
# 2127   38835     3  2017-01-01  1.144010e+09      0  571  0     나눔빌딩   1(단일)
# 2128   38835     3  2017-01-01  1.144010e+09      0  571  0     나눔빌딩   1(단일)
# 2129   38835     3  2017-01-01  1.144010e+09      0  571  0     나눔빌딩   1(단일)
# 2130   38835     3  2017-01-01  1.144010e+09      0  571  0     나눔빌딩   1(단일)
#
#       건물층구분코드  상가건물층주소 상가건물호주소  고시가격(원)  전유면적(㎡)  공용면적(㎡)           법정동명 폐지여부  \
# 2126        4        1     101  7620000    45.67   41.959  서울특별시 마포구 도화동   존재
# 2127        4        1     102  7620000    37.41   34.370  서울특별시 마포구 도화동   존재
# 2128        4        1     103  7620000    37.41   34.370  서울특별시 마포구 도화동   존재
# 2129        4        1     105  7655000    74.82   68.741  서울특별시 마포구 도화동   존재
# 2130        4        1     106  8496000    42.30   38.863  서울특별시 마포구 도화동   존재
#
#       법정동
# 2126  도화동
# 2127  도화동
# ...

# %%
df['법정동코드'] = df['법정동코드'].astype(int)

# %%
df.head()
# Out:
#       상가건물번호  건물구분        고시일자       법정동코드  특수지코드   번지  호 상가건물블록주소 상가건물동주소  \
# 2126   38835     3  2017-01-01  1144010400      0  571  0     나눔빌딩   1(단일)
# 2127   38835     3  2017-01-01  1144010400      0  571  0     나눔빌딩   1(단일)
# 2128   38835     3  2017-01-01  1144010400      0  571  0     나눔빌딩   1(단일)
# 2129   38835     3  2017-01-01  1144010400      0  571  0     나눔빌딩   1(단일)
# 2130   38835     3  2017-01-01  1144010400      0  571  0     나눔빌딩   1(단일)
#
#       건물층구분코드  상가건물층주소 상가건물호주소  고시가격(원)  전유면적(㎡)  공용면적(㎡)           법정동명 폐지여부  \
# 2126        4        1     101  7620000    45.67   41.959  서울특별시 마포구 도화동   존재
# 2127        4        1     102  7620000    37.41   34.370  서울특별시 마포구 도화동   존재
# 2128        4        1     103  7620000    37.41   34.370  서울특별시 마포구 도화동   존재
# 2129        4        1     105  7655000    74.82   68.741  서울특별시 마포구 도화동   존재
# 2130        4        1     106  8496000    42.30   38.863  서울특별시 마포구 도화동   존재
#
#       법정동
# 2126  도화동
# 2127  도화동
# 2128  도화동
# ...

# %%
df['법정동'].unique()
# Out:
# array(['도화동', '황학동', '대방동', '응암동', '봉천동', '화곡동', '연지동', '신림동', '가리봉동',
#        '독산동', '원효로3가', '녹번동', '역촌동', '신월동', '신사동', '장지동', '창동', '면목동',
#        '영등포동2가', '번동', '석관동', '당산동4가', '성수동1가', '문정동', '양평동4가', '길동',
#        '강일동', '천호동', '당산동5가', '묵동', '북가좌동', '노량진동', '신대방동', '거여동', '쌍문동',
#        '목동', '신내동', '화양동', '신당동', '방학동', '등촌동', '양평동3가', '대조동', '불광동',
#        '가락동', '구로동', '영등포동1가', '신원동', '중곡동', '수유동', '공덕동', '시흥동', '양평동6가',
#        '당산동6가', '양평동1가', '성수동2가', '마곡동', '서초동', '세곡동', '종암동', '영등포동8가',
#        '숭인동', '용답동', '남현동', '방배동', '삼성동', '신정동', '당산동', '오금동', '장안동',
#        '사당동', '영등포동4가', '구산동', '제기동', '가산동', '청량리동', '이문동', '상봉동', '중화동',
#        '망우동', '성북동1가', '동소문동6가', '동선동1가', '동선동3가', '안암동2가', '안암동3가',
#        '안암동4가', '보문동2가', '하월곡동', '장위동', '미아동', '적선동', '필운동', '당주동', '내수동',
#        '혜화동', '운니동', '인사동', '낙원동', '돈의동', '원남동', '효제동', '종로5가', '종로6가',
#        '명동2가', '연건동', '명륜4가', '창신동', '평창동', '부암동', '중림동', '남창동', '회현동1가',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 374889 entries, 2126 to 1015186
# Data columns (total 18 columns):
# 상가건물번호      374889 non-null int64
# 건물구분        374889 non-null int64
# 고시일자        374889 non-null object
# 법정동코드       374889 non-null int32
# 특수지코드       374889 non-null int64
# 번지          374889 non-null int64
# 호           374889 non-null int64
# 상가건물블록주소    374650 non-null object
# 상가건물동주소     364256 non-null object
# 건물층구분코드     374889 non-null int64
# 상가건물층주소     374889 non-null int64
# 상가건물호주소     374889 non-null object
# 고시가격(원)     374889 non-null int64
# 전유면적(㎡)     374889 non-null float64
# 공용면적(㎡)     374889 non-null float64
# 법정동명        374889 non-null object
# 폐지여부        374889 non-null object
# 법정동         374889 non-null object
# dtypes: float64(2), int32(1), int64(8), object(7)
# memory usage: 62.9+ MB

# %%
df = df.loc[df['건물구분']!=2]

# %%
df.columns
# Out:
# Index(['상가건물번호', '건물구분', '고시일자', '법정동코드', '특수지코드', '번지', '호', '상가건물블록주소',
#        '상가건물동주소', '건물층구분코드', '상가건물층주소', '상가건물호주소', '고시가격(원)', '전유면적(㎡)',
#        '공용면적(㎡)', '법정동명', '폐지여부', '법정동'],
#       dtype='object')

# %%
df_17 = df[['상가건물번호', '번지', '상가건물블록주소', '고시가격(원)', '전유면적(㎡)', '법정동명', '법정동']]

# %%
df_17['평당고시가격(원)'] = df_17['고시가격(원)']/df_17['전유면적(㎡)']
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_17.head()
# Out:
#       상가건물번호   번지 상가건물블록주소  고시가격(원)  전유면적(㎡)           법정동명  법정동  \
# 2126   38835  571     나눔빌딩  7620000    45.67  서울특별시 마포구 도화동  도화동
# 2127   38835  571     나눔빌딩  7620000    37.41  서울특별시 마포구 도화동  도화동
# 2128   38835  571     나눔빌딩  7620000    37.41  서울특별시 마포구 도화동  도화동
# 2129   38835  571     나눔빌딩  7655000    74.82  서울특별시 마포구 도화동  도화동
# 2130   38835  571     나눔빌딩  8496000    42.30  서울특별시 마포구 도화동  도화동
#
#           평당고시가격(원)
# 2126  166849.135100
# 2127  203688.853248
# 2128  203688.853248
# 2129  102312.215985
# 2130  200851.063830

# %%
price = df_17.groupby(['상가건물번호', '상가건물블록주소', '법정동명', '법정동', '번지'])['평당고시가격(원)'].mean().reset_index()

# %%
import numpy as np

# %%
price.head()
# Out:
#    상가건물번호   상가건물블록주소             법정동명   법정동   번지      평당고시가격(원)
# 0       1     신부파스칼텔   서울특별시 동대문구 장안동   장안동  431   70607.558949
# 1       2     청암오피스텔   서울특별시 동대문구 장안동   장안동  466   32858.558637
# 2       3       미주상가  서울특별시 동대문구 청량리동  청량리동  235   43513.644766
# 3       4  청량리현대코아동관  서울특별시 동대문구 청량리동  청량리동  738  107859.707487
# 4       5        파크빌   서울특별시 동대문구 이문동   이문동  257   62146.785044

# %%
price['평당고시가격(원)'] = round(price['평당고시가격(원)']).astype(int)
price.head()
# Out:
#    상가건물번호   상가건물블록주소             법정동명   법정동   번지  평당고시가격(원)
# 0       1     신부파스칼텔   서울특별시 동대문구 장안동   장안동  431      70608
# 1       2     청암오피스텔   서울특별시 동대문구 장안동   장안동  466      32859
# 2       3       미주상가  서울특별시 동대문구 청량리동  청량리동  235      43514
# 3       4  청량리현대코아동관  서울특별시 동대문구 청량리동  청량리동  738     107860
# 4       5        파크빌   서울특별시 동대문구 이문동   이문동  257      62147

# %%
price.sort_values(by='평당고시가격(원)', ascending=False)
# Out:
#       상가건물번호      상가건물블록주소               법정동명     법정동    번지  평당고시가격(원)
# 817     4231      제일평화시장상가       서울특별시 중구 신당동     신당동   775    8921790
# 81       136        에어리어식스       서울특별시 중구 신당동     신당동   776    3364786
# 838     4331       남대문코코클럽       서울특별시 중구 남창동     남창동    52    2959045
# 822     4239         몰리지패션     서울특별시 중구 충무로2가   충무로2가    63    2848366
# 79       133         청평화시장       서울특별시 중구 신당동     신당동   217    2700640
# 819     4233       신평화패션타운       서울특별시 중구 신당동     신당동   217    2181706
# 78       132         아트프라자       서울특별시 중구 신당동     신당동   213    2095242
# 64       109        명동캣츠빌딩     서울특별시 중구 충무로1가   충무로1가    24    1957082
# 63       108        밀리오레명동     서울특별시 중구 충무로1가   충무로1가    24    1920240
# 1511   22066           디오트       서울특별시 중구 신당동     신당동   193    1893327
# 48        76       동대문종합상가     서울특별시 종로구 종로6가    종로6가   262    1881918
# 49        77       동대문종합상가     서울특별시 종로구 종로6가    종로6가   289    1869760
# ...
