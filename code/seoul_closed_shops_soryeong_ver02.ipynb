# %%
import pandas as pd

# %%
df = pd.read_csv('df_filled.csv')

# %%
df.head()
# Out:
#                                 address        lat         lng    구      년도  \
# 0           서울특별시 은평구 신사동  17번지 11호  2층  37.598980  126.910005  은평구  2014.0
# 1  서울특별시 은평구 수색동  75번지  DMC 자이상가 1층108호  37.579561  126.898666  은평구  2014.0
# 2            서울특별시 은평구 대조동  185번지 16호    37.618575  126.921100  은평구  1999.0
# 3     서울특별시 은평구 갈현동  506번지 9호  103,104호  37.616395  126.912951  은평구  2013.0
# 4            서울특별시 은평구 응암동  72번지 3호  1층  37.600772  126.929972  은평구  2016.0
#
#          업소명    업종명     업태명  영업자시작년도      영업자시작일    폐업년도        폐업일자
# 0       2월7일  일반음식점   호프/통닭   2014.0  20140224.0     NaN         NaN
# 1      오봉도시락  휴게음식점  일반조리판매   2014.0  20141010.0     NaN         NaN
# 2       명송회집  일반음식점      분식   2013.0  20130308.0  2013.0  20131220.0
# 3    장충왕족발보쌈  일반음식점   호프/통닭   2013.0  20130808.0  2014.0  20141226.0
# 4  예쁜 뽀들이 함바  일반음식점      한식   2016.0  20161129.0     NaN         NaN

# %%
def searching(df, area, year=None, status=None):
    df_area = df[df['address'].str.contains(area)]
    if year != None:
        if status == 'opened':
            df_area = df_area.loc[df_area['영업자시작년도'] == year]
        elif status == 'closed':
            df_area = df_area.loc[df_area['폐업년도'] == year]
        elif status == 'on_sale':
            df_area = df_area.loc[(df_area['영업자시작년도'] <= year) & ((df_area['폐업년도'] > year) | df_area['폐업년도'].isnull())]
        else:
            return 'you missed status(opened or closed or on_sale)'
    
    return df_area

# %%
yeonnam_2015.shape
# Out:
# (320, 12)

# %%
yeonnam_2015 = searching(df, '연남동', year=2015, status='on_sale')

(ggplot(yeonnam_2015[['lat', 'lng']])
 + aes(x='lat', y='lng')
 + geom_point(size=3, alpha=0.5, color='red')
)
# Out:
# C:\Users\rlath\Anaconda3\lib\site-packages\pandas\core\generic.py:4384: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   object.__getattribute__(self, name)
# C:\Users\rlath\Anaconda3\lib\site-packages\pandas\core\generic.py:4385: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   return object.__setattr__(self, name, value)
# C:\Users\rlath\Anaconda3\lib\site-packages\plotnine\layer.py:450: UserWarning: geom_point : Removed 1 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# <ggplot: (-9223371913876931391)>

# %%
sanggae_2015.shape
# Out:
# (1736, 12)

# %%
sanggae_2015 = searching(df, '상계동', year=2015, status='on_sale')

(ggplot(sanggae_2015[['lat', 'lng']])
 + aes(x='lat', y='lng')
 + geom_point(size=3, alpha=0.5, color='red')
)
# Out:
# C:\Users\rlath\Anaconda3\lib\site-packages\pandas\core\generic.py:4384: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   object.__getattribute__(self, name)
# C:\Users\rlath\Anaconda3\lib\site-packages\pandas\core\generic.py:4385: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   return object.__setattr__(self, name, value)
# C:\Users\rlath\Anaconda3\lib\site-packages\plotnine\layer.py:450: UserWarning: geom_point : Removed 24 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# <ggplot: (122977871224)>

# %%
df_seoul = df.loc[(df['영업자시작년도'] <= 2015) & ((df['폐업년도'] > 2015) | df['폐업년도'].isnull())]

# %%
(ggplot(df_seoul[['lng', 'lat']])
 + aes(x='lng', y='lat')
 + geom_point(size=0.01, alpha=0.01, color='red')
)
# Out:
# C:\Users\rlath\Anaconda3\lib\site-packages\pandas\core\generic.py:4384: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   object.__getattribute__(self, name)
# C:\Users\rlath\Anaconda3\lib\site-packages\pandas\core\generic.py:4385: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   return object.__setattr__(self, name, value)
# C:\Users\rlath\Anaconda3\lib\site-packages\plotnine\layer.py:450: UserWarning: geom_point : Removed 218 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# <ggplot: (122977469020)>

# %%
df_seoul_2007 = df.loc[(df['영업자시작년도'] <= 2007) & ((df['폐업년도'] > 2007) | df['폐업년도'].isnull())]
df_seoul_2007.shape, df_seoul_2017.shape
# Out:
# ((57427, 12), (148856, 12))

# %%
df_jr_2007 = df_seoul_2007.loc[df['구'] == '중랑구']

# %%
(ggplot(df_jr_2007[['lng', 'lat']])
 + aes(x='lng', y='lat')
 + geom_point(size=0.5, alpha=0.1, color='blue')
)
# Out:
# C:\Users\rlath\Anaconda3\lib\site-packages\pandas\core\generic.py:4384: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   object.__getattribute__(self, name)
# C:\Users\rlath\Anaconda3\lib\site-packages\pandas\core\generic.py:4385: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   return object.__setattr__(self, name, value)
# <ggplot: (122977814718)>

# %%
df_seoul_2017 = df.loc[(df['영업자시작년도'] <= 2017) & ((df['폐업년도'] > 2017) | df['폐업년도'].isnull())]

# %%
df_jr_2017 = df_seoul_2017.loc[df['구'] == '중랑구']

# %%
(ggplot(df_jr_2017[['lng', 'lat']])
 + aes(x='lng', y='lat')
 + geom_point(size=0.5, alpha=0.1, color='blue')
)
# Out:
# C:\Users\rlath\Anaconda3\lib\site-packages\pandas\core\generic.py:4384: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   object.__getattribute__(self, name)
# C:\Users\rlath\Anaconda3\lib\site-packages\pandas\core\generic.py:4385: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   return object.__setattr__(self, name, value)
# C:\Users\rlath\Anaconda3\lib\site-packages\plotnine\layer.py:450: UserWarning: geom_point : Removed 22 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# <ggplot: (122978459207)>

# %%
yeonnam_2015 = yeonnam_2015.loc[(yeonnam_2015['영업자시작년도'] == 2015) | (yeonnam_2015['폐업년도'] == 2015) |\
                                ((yeonnam_2015['영업자시작년도'] < 2015) & ((yeonnam_2015['폐업년도'] > 2015)|(yeonnam_2015['폐업년도'].isnull())))]

# %%
yeonnam_2015.loc[yeonnam_2015['영업자시작년도'] == 2015, 'color'] = 'yellow'
yeonnam_2015.loc[yeonnam_2015['폐업년도'] == 2015, 'color'] = 'red'
yeonnam_2015.loc[(yeonnam_2015['영업자시작년도'] < 2015) & ((yeonnam_2015['폐업년도'] > 2015)|(yeonnam_2015['폐업년도'].isnull())), 'color'] = 'blue'

# %%
yeonnam_2015
# Out:
#                                           address        lat         lng    구  \
# 255211                  서울특별시 마포구 연남동  561번지 1호    37.561356  126.920216  마포구
# 260608  2014.0                       레체(LECHE)  제과점영업     제과점영업   2014.0
# 260772  2011.0                            서영까페  일반음식점        까페   2011.0
# 260807  2013.0                           크래프트원  일반음식점     호프/통닭   2013.0
# 260813  2011.0                         (주)커피집단  일반음식점        까페   2011.0
# 260815  2011.0                          전주삼백식당  일반음식점        한식   2011.0
# 260818  2011.0                          연남동올레길  일반음식점        까페   2011.0
# 260853  2011.0                             히메지  일반음식점        한식   2011.0
# 260855  2011.0                           커피비앤비  일반음식점        까페   2011.0
# 260877  1991.0                          페리카나치킨  일반음식점     호프/통닭   2001.0
# 260896  2010.0                          최사장네 닭  일반음식점        한식   2013.0
# 260954  2012.0                             시실리  일반음식점     호프/통닭   2012.0
# ...        ...                             ...    ...       ...      ...
# 310226  2015.0                             대환영  일반음식점     호프/통닭   2015.0
# 310231  2014.0                          오복수산시장  일반음식점     호프/통닭   2014.0
# 310232  2014.0                            오씨반주  일반음식점     호프/통닭   2014.0
# 310283  2014.0                           연남고깃집  일반음식점     호프/통닭   2014.0
# 310346  2015.0              에스에프베이글(SF Bagels)  제과점영업     제과점영업   2015.0
# 310365  1995.0                              별솔  일반음식점        한식   2011.0
# 310375  2015.0                         리틀프레스커피  휴게음식점       커피숍   2015.0
# 310376  2015.0                사이커피(sai coffee)  휴게음식점       커피숍   2015.0
# 310482  1987.0                            연남식당  일반음식점       경양식   1996.0
# 310483  2014.0  브하쎄커피앤티 (brassee Coffee & Tea)  휴게음식점      전통찻집   2014.0
# 310636  2003.0                            김밥세상  일반음식점        분식   2014.0
# 310660  2015.0                           짐레서피즈  일반음식점        한식   2015.0
# 310677  2011.0                           현주네식당  일반음식점        한식   2011.0
# 310822  2015.0                              별관  일반음식점     호프/통닭   2015.0
# 310912  2013.0                          라이라이라이  일반음식점       경양식   2013.0
# 311472  2014.0                             요코쵸  일반음식점        일식   2014.0
# 311540  2014.0                              나베  일반음식점        일식   2014.0
# 311699  2013.0                               정  일반음식점        까페   2013.0
# 312016  2014.0                          채널1969  일반음식점     호프/통닭   2014.0
# 312403  2012.0                        비스트로티앤제인  일반음식점       경양식   2012.0
# 312838  2007.0                              얼랑  일반음식점        까페   2014.0
# 312932  2002.0                           영동감자탕  일반음식점        한식   2002.0
# 313071  2015.0                          화성구이포차  일반음식점       중국식   2015.0
# 313072  2015.0                         대만야시장2호  일반음식점       중국식   2015.0
# 314087  2015.0                           살롱드라싸  일반음식점        까페   2015.0
# 314649  2014.0            무아펑츄어(muah punctual)  일반음식점        까페   2014.0
# 314650  2014.0            무아펑츄어(muah punctual)  일반음식점        까페   2014.0
# 314935  2004.0                            더리퀴드  일반음식점        까페   2009.0
# 314936  2004.0                            더리퀴드  일반음식점        까페   2009.0
# 315084  2015.0            젠틀키친(Gentle Kitchen)  일반음식점     호프/통닭   2015.0
#
#             영업자시작일    폐업년도        폐업일자   color
# 255211  20080305.0     NaN         NaN    blue
# 255222  20020118.0     NaN         NaN    blue
# 255276  20140102.0     NaN         NaN    blue
# 258407  20090916.0     NaN         NaN    blue
# 258964  20100316.0     NaN         NaN    blue
# 259226  20110607.0     NaN         NaN    blue
# 259266  20100527.0     NaN         NaN    blue
# 259312  20110118.0  2017.0  20171214.0    blue
# 259915  20100222.0  2017.0  20170921.0    blue
# 260109  20130717.0     NaN         NaN    blue
# 260130  20100722.0     NaN         NaN    blue
# 260131  20100625.0     NaN         NaN    blue
# 260140  20100830.0     NaN         NaN    blue
# 260154  20100716.0     NaN         NaN    blue
# 260206  20110112.0  2015.0  20150319.0     red
# 260226  20100816.0  2016.0  20160215.0    blue
# 260323  20140429.0     NaN         NaN    blue
# 260343  20121119.0  2017.0  20170904.0    blue
# 260359  20130624.0     NaN         NaN    blue
# 260608  20140829.0  2015.0  20150616.0     red
# 260772  20110719.0     NaN         NaN    blue
# 260807  20130607.0     NaN         NaN    blue
# 260813  20110627.0     NaN         NaN    blue
# 260815  20110628.0     NaN         NaN    blue
# 260818  20110704.0  2016.0  20160215.0    blue
# 260853  20110623.0     NaN         NaN    blue
# 260855  20110721.0     NaN         NaN    blue
# 260877  20011114.0     NaN         NaN    blue
# 260896  20130121.0     NaN         NaN    blue
# 260954  20120810.0     NaN         NaN    blue
# ...            ...     ...         ...     ...
# 310226  20151207.0     NaN         NaN  yellow
# 310231  20140409.0     NaN         NaN    blue
# 310232  20140409.0     NaN         NaN    blue
# 310283  20140404.0     NaN         NaN    blue
# 310346  20151029.0     NaN         NaN  yellow
# 310365  20110921.0     NaN         NaN    blue
# 310375  20150818.0     NaN         NaN  yellow
# 310376  20150818.0     NaN         NaN  yellow
# 310482  19960327.0     NaN         NaN    blue
# 310483  20141208.0     NaN         NaN    blue
# 310636  20140805.0     NaN         NaN    blue
# 310660  20150717.0  2017.0  20170818.0  yellow
# 310677  20110406.0     NaN         NaN    blue
# 310822  20150716.0     NaN         NaN  yellow
# 310912  20130806.0     NaN         NaN    blue
# 311472  20141212.0     NaN         NaN    blue
# 311540  20141124.0     NaN         NaN    blue
# 311699  20130219.0     NaN         NaN    blue
# 312016  20140227.0     NaN         NaN    blue
# 312403  20120605.0     NaN         NaN    blue
# 312838  20141016.0     NaN         NaN    blue
# 312932  20021018.0     NaN         NaN    blue
# 313071  20150930.0     NaN         NaN  yellow
# 313072  20150930.0     NaN         NaN  yellow
# 314087  20150515.0     NaN         NaN  yellow
# 314649  20140411.0     NaN         NaN    blue
# 314650  20140411.0     NaN         NaN    blue
# 314935  20090525.0     NaN         NaN    blue
# 314936  20090525.0     NaN         NaN    blue
# 315084  20151119.0     NaN         NaN  yellow
#
# [351 rows x 13 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-105-4e6eaf074208> in <module>()
# ----> 1 help(str.lower())
#
# TypeError: descriptor 'lower' of 'str' object needs an argument

# %%
yeonnam_2015['color'].lower()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-102-93d65a651873> in <module>()
# ----> 1 yeonnam_2015['color'].lower()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'lower'

# %%
from plotnine import *

# %%
(ggplot(yeonnam_2015[['lat', 'lng']])
 + aes(x='lat', y='lng')
 + geom_point(size=3, alpha=0.6, color=yeonnam_2015['color'].lower())
#  + ggtitle('서울시 카페 지도')
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-101-a1d6788ec253> in <module>()
#       2 (ggplot(yeonnam_2015[['lat', 'lng']])
#       3  + aes(x='lat', y='lng')
# ----> 4  + geom_point(size=3, alpha=0.6, color=yeonnam_2015['color'].lower())
#       5 #  + ggtitle('서울시 카페 지도')
#       6 )
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'lower'
