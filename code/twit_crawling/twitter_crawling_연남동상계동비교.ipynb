# %% [markdown]
# # Twitter Crawling - 연남동
#
# ## tweepy의 문제점
# 최근 7일밖에 가져오지 못함.
#
# 우리가 보려는 것은 과거부터 현재데이터이므로 twitter에서 제공하는 API를 사용할수 없다.
#
# 과거 데이터를 가져오려면 돈을 지불해야 함
#
# ## 극복방안
# selenium을 통해 동적 크롤링을 했다.
#
# chrome은 느리다는 말이 있어서 firefox를 이용했고 geckodriver로 크롤링 시행
#
# '연남' 키워드 검색 -> 내연남이 너무 많이 포함됨 -> 내연남 키워드를 빼도록 url에 설정했지만 어찌된일인지 내연남 트윗들만 검색됨(?,,) -> '연남동'으로 키워드 대체
#
# ## 한계점
# 중간중간 트래픽이 폭주했다고..
#
# 모든 데이터를 뽑는데 시간이 너무 오래 걸린다. 201201, 201301 이런식으로 각 년도 1월달만 뽑으려 했으나 31일씩 하는데도 오래걸려서 오히려 각 월별 1일을 뽑아 비교해보는게 어떨가 싶었다

# %%
from bs4 import BeautifulSoup
import requests
from selenium import webdriver
from selenium.webdriver.firefox.firefox_binary import  FirefoxBinary
from selenium.webdriver.common.desired_capabilities import  DesiredCapabilities
import time
from selenium.webdriver.common.keys import Keys
import datetime as dt
import pandas as pd

# %%
binary=FirefoxBinary('C:/Program Files/Mozilla Firefox/firefox.exe')
browser=webdriver.Firefox(executable_path='geckodriver.exe',firefox_binary=binary)

# %%
startdate=dt.date(year=2018,month=1,day=1)
untildate=dt.date(year=2018,month=1,day=2)
enddate=dt.date(year=2018,month=2,day=1)

# %%
totalfreq=[]
while not enddate==startdate:
    url='https://twitter.com/search?q=연남동%20since%3A'+str(startdate)+'%20until%3A'+str(untildate)+'&amp;amp;amp;amp;amp;amp;lang=eg'
    browser.get(url)
    html = browser.page_source
    soup=BeautifulSoup(html,'html.parser')
    
    lastHeight = browser.execute_script("return document.body.scrollHeight")
    while True:
        dailyfreq={'Date':startdate}
        wordfreq=0
        tweets=soup.find_all("p", {"class": "TweetTextSize"})
        wordfreq+=len(tweets)
            
        browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(3)
        
        newHeight = browser.execute_script("return document.body.scrollHeight")
        print(newHeight)
        if newHeight != lastHeight:
            html = browser.page_source
            soup=BeautifulSoup(html,'html.parser')
            tweets=soup.find_all("p", {"class": "TweetTextSize"})
            wordfreq=len(tweets)
        else:
            dailyfreq['Frequency']=wordfreq
            wordfreq=0
            totalfreq.append(dailyfreq)
            startdate=untildate
            untildate+=dt.timedelta(days=1)
            dailyfreq={}
            break
        lastHeight = newHeight
# Out:
# 8277
# 8277
# 9309
# 9327
# 9327
# 4086
# 4086
# 8758
# 8758
# 6799
# 6817
# 6817
# 8454
# 8562
# 8562
# 7779
# 7779
# 8899
# 8917
# 8917
# 9213
# 9231
# 9231
# 7664
# 12890
# 15510
# 19127
# 19145
# 19145
# 9917
# 10137
# 10137
# 6605
# 6605
# 7195
# 7195
# 7056
# 7056
# 8531
# 8639
# 8639
# 7990
# 8271
# 8271
# 7931
# 8862
# 8862
# 10552
# 10552
# 7466
# 7484
# 7484
# 9210
# 9228
# 9228
# 6835
# 6835
# 8196
# 8196
# 6350
# 6586
# 6586
# 8671
# 8689
# 8689
# 8303
# 8357
# 8357
# 7699
# 7699
# 7728
# 7728
# 7881
# 7881
# 8659
# 8677
# 8677
# 6311
# 6561
# 6793
# 6793
# 8564
# 8564

# %%
df_201801 = pd.DataFrame(totalfreq)

# %%
df_201701 = pd.DataFrame(totalfreq)

# %%
df_201601 = pd.DataFrame(totalfreq)

# %%
df_201501 = pd.DataFrame(totalfreq)

# %%
df_201401 = pd.DataFrame(totalfreq)

# %%
df_201301 = pd.DataFrame(totalfreq)

# %%
df_201201 = pd.DataFrame(totalfreq)

# %%
df_201201
# Out:
#           Date  Frequency
# 0   2012-01-01          6
# 1   2012-01-02         12
# 2   2012-01-03         11
# 3   2012-01-04         13
# 4   2012-01-05         14
# 5   2012-01-06         10
# 6   2012-01-07         14
# 7   2012-01-08         13
# 8   2012-01-09          8
# 9   2012-01-10         15
# 10  2012-01-11          8
# 11  2012-01-12          8
# 12  2012-01-13         14
# 13  2012-01-14         12
# 14  2012-01-15         16
# 15  2012-01-16         14
# 16  2012-01-17          9
# 17  2012-01-18          4
# 18  2012-01-19          9
# 19  2012-01-20          9
# 20  2012-01-21         11
# 21  2012-01-22          6
# 22  2012-01-23          2
# 23  2012-01-24          3
# 24  2012-01-25         12
# 25  2012-01-26         11
# 26  2012-01-27         23
# 27  2012-01-28         12
# 28  2012-01-29         10
# 29  2012-01-30          6
# 30  2012-01-31         24

# %%
df_201301
# Out:
#           Date  Frequency
# 0   2013-01-01          6
# 1   2013-01-02         11
# 2   2013-01-03         22
# 3   2013-01-04         33
# 4   2013-01-05         18
# 5   2013-01-06         19
# 6   2013-01-07         22
# 7   2013-01-08          9
# 8   2013-01-09         14
# 9   2013-01-10         15
# 10  2013-01-11         25
# 11  2013-01-12         27
# 12  2013-01-13         19
# 13  2013-01-14         18
# 14  2013-01-15         19
# 15  2013-01-16         12
# 16  2013-01-17         18
# 17  2013-01-18         21
# 18  2013-01-19         21
# 19  2013-01-20         13
# 20  2013-01-21         20
# 21  2013-01-22         18
# 22  2013-01-23         21
# 23  2013-01-24         27
# 24  2013-01-25         22
# 25  2013-01-26         10
# 26  2013-01-27         20
# 27  2013-01-28         24
# 28  2013-01-29         13
# 29  2013-01-30         16
# 30  2013-01-31         27

# %%
df_201401
# Out:
#           Date  Frequency
# 0   2014-01-01         12
# 1   2014-01-02         15
# 2   2014-01-03         26
# 3   2014-01-04         19
# 4   2014-01-05         16
# 5   2014-01-06         15
# 6   2014-01-07         23
# 7   2014-01-08         17
# 8   2014-01-09         37
# 9   2014-01-10         35
# 10  2014-01-11         24
# 11  2014-01-12         39
# 12  2014-01-13         37
# 13  2014-01-14         23
# 14  2014-01-15         17
# 15  2014-01-16         21
# 16  2014-01-17         21
# 17  2014-01-18         23
# 18  2014-01-19         15
# 19  2014-01-20         16
# 20  2014-01-21         23
# 21  2014-01-22         19
# 22  2014-01-23         19
# 23  2014-01-24         25
# 24  2014-01-25         34
# 25  2014-01-26         29
# 26  2014-01-27         31
# 27  2014-01-28         18
# 28  2014-01-29         33
# 29  2014-01-30         10
# 30  2014-01-31          6

# %%
df_201501
# Out:
#           Date  Frequency
# 0   2015-01-01         13
# 1   2015-01-02         17
# 2   2015-01-03         20
# 3   2015-01-04         32
# 4   2015-01-05         23
# 5   2015-01-06         24
# 6   2015-01-07         35
# 7   2015-01-08         27
# 8   2015-01-09         31
# 9   2015-01-10         20
# 10  2015-01-11         24
# 11  2015-01-12         23
# 12  2015-01-13         21
# 13  2015-01-14         20
# 14  2015-01-15         16
# 15  2015-01-16         23
# 16  2015-01-17         32
# 17  2015-01-18         31
# 18  2015-01-19         26
# 19  2015-01-20         28
# 20  2015-01-21         30
# 21  2015-01-22         31
# 22  2015-01-23         39
# 23  2015-01-24         36
# 24  2015-01-25         20
# 25  2015-01-26         38
# 26  2015-01-27         17
# 27  2015-01-28         29
# 28  2015-01-29         27
# 29  2015-01-30         26
# 30  2015-01-31         31

# %%
df_201601
# Out:
#           Date  Frequency
# 0   2016-01-01         15
# 1   2016-01-02         23
# 2   2016-01-03         27
# 3   2016-01-04         15
# 4   2016-01-05         23
# 5   2016-01-06         21
# 6   2016-01-07         24
# 7   2016-01-08         23
# 8   2016-01-09         26
# 9   2016-01-10         37
# 10  2016-01-11         26
# 11  2016-01-12         33
# 12  2016-01-13         22
# 13  2016-01-14         33
# 14  2016-01-15         31
# 15  2016-01-16         39
# 16  2016-01-17         38
# 17  2016-01-18         20
# 18  2016-01-19         20
# 19  2016-01-20         17
# 20  2016-01-21         37
# 21  2016-01-22         16
# 22  2016-01-23         25
# 23  2016-01-24         23
# 24  2016-01-25         20
# 25  2016-01-26         31
# 26  2016-01-27         26
# 27  2016-01-28         28
# 28  2016-01-29         23
# 29  2016-01-30         19
# 30  2016-01-31         28

# %%
df_201701
# Out:
#           Date  Frequency
# 0   2017-01-01         34
# 1   2017-01-02         39
# 2   2017-01-03         35
# 3   2017-01-04         36
# 4   2017-01-05         37
# 5   2017-01-06         39
# 6   2017-01-07         38
# 7   2017-01-08         35
# 8   2017-01-09         35
# 9   2017-01-10         22
# 10  2017-01-11         29
# 11  2017-01-12         38
# 12  2017-01-13         33
# 13  2017-01-14         40
# 14  2017-01-15         40
# 15  2017-01-16         36
# 16  2017-01-17         33
# 17  2017-01-18         39
# 18  2017-01-19         32
# 19  2017-01-20         31
# 20  2017-01-21         39
# 21  2017-01-22         36
# 22  2017-01-23         35
# 23  2017-01-24         24
# 24  2017-01-25         37
# 25  2017-01-26         28
# 26  2017-01-27         24
# 27  2017-01-28         18
# 28  2017-01-29         26
# 29  2017-01-30         24
# 30  2017-01-31         23

# %%
df_201801
# Out:
#           Date  Frequency
# 0   2018-01-01         37
# 1   2018-01-02         37
# 2   2018-01-03         25
# 3   2018-01-04         36
# 4   2018-01-05         38
# 5   2018-01-06         38
# 6   2018-01-07         39
# 7   2018-01-08         39
# 8   2018-01-09         37
# 9   2018-01-10         87
# 10  2018-01-11         39
# 11  2018-01-12         37
# 12  2018-01-13         36
# 13  2018-01-14         33
# 14  2018-01-15         41
# 15  2018-01-16         41
# 16  2018-01-17         37
# 17  2018-01-18         37
# 18  2018-01-19         34
# 19  2018-01-20         40
# 20  2018-01-21         38
# 21  2018-01-22         37
# 22  2018-01-23         39
# 23  2018-01-24         32
# 24  2018-01-25         40
# 25  2018-01-26         35
# 26  2018-01-27         38
# 27  2018-01-28         36
# 28  2018-01-29         40
# 29  2018-01-30         35
# 30  2018-01-31         33

# %%
df_twit_sum = pd.DataFrame(data={'year':['2012','2013','2014','2015','2016','2017','2018'],
                   'data':[df_201201['Frequency'].sum(),df_201301['Frequency'].sum(),df_201401['Frequency'].sum(),
                         df_201501['Frequency'].sum(),df_201601['Frequency'].sum(),df_201701['Frequency'].sum(),
                         df_201801['Frequency'].sum()]})

# %%
df_twit_sum
# Out:
#    year  data
# 0  2012   339
# 1  2013   580
# 2  2014   698
# 3  2015   806
# 4  2016   789
# 5  2017  1015
# 6  2018  1191

# %%
df_yn_twit_sum = pd.DataFrame(data={'Year':['2012','2013','2014','2015','2016','2017','2018'],
                                    'Frequency':[339,580,698,806,789,1015,1191]})
df_yn_twit_sum['loc'] = '연남동'
df_yn_twit_sum
# Out:
#    Year  Frequency  loc
# 0  2012        339  연남동
# 1  2013        580  연남동
# 2  2014        698  연남동
# 3  2015        806  연남동
# 4  2016        789  연남동
# 5  2017       1015  연남동
# 6  2018       1191  연남동

# %% [markdown]
# ## 상계동 크롤링

# %%
df_sg = []

# %%
for y in [2012,2013,2014,2015,2016,2017,2018]:
    startdate=dt.date(year=y,month=1,day=1)
    untildate=dt.date(year=y,month=1,day=2)
    enddate=dt.date(year=y,month=2,day=1)
    
    totalfreq=[]
    while not enddate==startdate:
        url='https://twitter.com/search?q=상계동%20since%3A'+str(startdate)+'%20until%3A'+str(untildate)+'&amp;amp;amp;amp;amp;amp;lang=eg'
        browser.get(url)
        html = browser.page_source
        soup=BeautifulSoup(html,'html.parser')

        lastHeight = browser.execute_script("return document.body.scrollHeight")
        while True:
            dailyfreq={'Date':startdate}
            wordfreq=0
            tweets=soup.find_all("p", {"class": "TweetTextSize"})
            wordfreq+=len(tweets)

            browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            time.sleep(3)

            newHeight = browser.execute_script("return document.body.scrollHeight")
            print(newHeight)
            if newHeight != lastHeight:
                html = browser.page_source
                soup=BeautifulSoup(html,'html.parser')
                tweets=soup.find_all("p", {"class": "TweetTextSize"})
                wordfreq=len(tweets)
            else:
                dailyfreq['Frequency']=wordfreq
                wordfreq=0
                totalfreq.append(dailyfreq)
                startdate=untildate
                untildate+=dt.timedelta(days=1)
                dailyfreq={}
                break
            lastHeight = newHeight
    
    df_sg.append(totalfreq)
# Out:
# 987
# 987
# 2305
# 2656
# 2786
# 2786
# 1667
# 1887
# 1887
# 987
# 987
# 2892
# 2892
# 2029
# 2249
# 2249
# 1395
# 1635
# 1875
# 1875
# 1140
# 1140
# 1535
# 1535
# 1603
# 1713
# 1803
# 1803
# 1951
# 1951
# 1707
# 1707
# 1415
# 1415
# 816
# 1400
# 1557
# 1557
# 1725
# 1855
# 1985
# 1985
# 1016
# 2501
# 2902
# 3172
# 3442
# 3713
# 3803
# 3803
# 1653
# 987
# 1002
# 1295
# 1385
# 1385
# 2061
# 2061
# 987
# 1290
# 1312
# 2333
# 2333
# 1659
# 1437
# 1437
# 3442
# 3442
# 1505
# 1505
# 1759
# 1889
# 2019
# 2019
# 1933
# 1371
# 1371
# 1054
# 987
# 2111
# 2111
# 2327
# 2568
# 2568
# 1777
# 1777
# 1833
# 1833
# 2461
# 2461
# 987
# 1146
# 1146
# 1565
# 1236
# 1236
# 1096
# 1487
# 1487
# 2347
# 2477
# 2477
# 987
# 1276
# 1276
# 987
# 987
# 987
# 987
# 987
# 2535
# 2845
# 2845
# 987
# 987
# 987
# 2081
# 2081
# 987
# 987
# 1265
# 987
# 987
# 1336
# 1336
# 987
# 1137
# 987
# 987
# 1585
# 1293
# 987
# 1117
# 2395
# 2535
# 2535
# 987
# 987
# 987
# 987
# 987
# 987
# 987
# 2307
# 2587
# 2727
# 2868
# 2868
# 987
# 1735
# 1955
# 2065
# 2065
# 987
# 987
# 1795
# 1795
# 1321
# 1461
# 1461
# 987
# 1093
# 987
# 987
# 1286
# 1286
# 987
# 987
# 1164
# 1494
# 987
# 1267
# 1267
# 987
# 987
# 987
# 987
# 987
# 1192
# 2594
# 2714
# 2714
# 3315
# 3315
# 987
# 1787
# 1897
# 2007
# 2007
# 987
# 1364
# 1327
# 1437
# 1547
# 1657
# 1657
# 1376
# 1487
# 1487
# 987
# 987
# 987
# 987
# 987
# 987
# 987
# 987
# 987
# 1216
# 1316
# 1136
# 1136
# 987
# 1172
# 987
# 987
# 987
# 1303
# 987
# 987
# 987
# 987
# 1038
# 987
# 987
# 987
# 987
# 1064
# 987
# 1443
# 987
# 987
# 6208
# 6208
# 3119
# 3119
# 987
# 987
# 987
# 987
# 3590
# 3680
# 3790
# 3790
# 987
# 987
# 987
# 987
# 987
# 987
# 987
# 987
# 987
# 1056
# 987
# 987
# 987
# 1000
# 987
# 987
# 987
# 987
# 987
# 987
# 987
# 987
# 987
# 987
# 987
# 987
# 987
# 1093
# 987
# 987
# 1814
# 987
# 987
# 987
# 987
# 987
# 1508
# 1859
# 1144
# 1261
# 1261
# 987
# 987
# 2168
# 2168
# 1838
# 987
# 1344
# 2875
# 2444
# 2444
# 987
# 1008
# 987
# 2519
# 2519
# 1038
# 1722
# 2359
# 2359
# 996
# 2996
# 3114
# 3114
# 3400
# 4048
# 4048
# 3322
# 3412
# 3412
# 5558
# 5558
# 2754
# 3755
# 4403
# 4403
# 1462
# 1438
# 2395
# 2395
# 2200
# 2828
# 3475
# 3475
# 2529
# 2529

# %%
df_sg
# Out:
# [[{'Date': datetime.date(2012, 1, 1), 'Frequency': 4},
#   {'Date': datetime.date(2012, 1, 2), 'Frequency': 21},
#   {'Date': datetime.date(2012, 1, 3), 'Frequency': 16},
#   {'Date': datetime.date(2012, 1, 4), 'Frequency': 5},
#   {'Date': datetime.date(2012, 1, 5), 'Frequency': 19},
#   {'Date': datetime.date(2012, 1, 6), 'Frequency': 17},
#   {'Date': datetime.date(2012, 1, 7), 'Frequency': 14},
#   {'Date': datetime.date(2012, 1, 8), 'Frequency': 7},
#   {'Date': datetime.date(2012, 1, 9), 'Frequency': 12},
#   {'Date': datetime.date(2012, 1, 10), 'Frequency': 14},
#   {'Date': datetime.date(2012, 1, 11), 'Frequency': 14},
#   {'Date': datetime.date(2012, 1, 12), 'Frequency': 12},
#   {'Date': datetime.date(2012, 1, 13), 'Frequency': 10},
#   {'Date': datetime.date(2012, 1, 14), 'Frequency': 5},
#   {'Date': datetime.date(2012, 1, 15), 'Frequency': 9},
#   {'Date': datetime.date(2012, 1, 16), 'Frequency': 11},
#   {'Date': datetime.date(2012, 1, 17), 'Frequency': 15},
#   {'Date': datetime.date(2012, 1, 18), 'Frequency': 7},
#   {'Date': datetime.date(2012, 1, 19), 'Frequency': 33},
#   {'Date': datetime.date(2012, 1, 20), 'Frequency': 11},
#   {'Date': datetime.date(2012, 1, 21), 'Frequency': 5},
#   {'Date': datetime.date(2012, 1, 22), 'Frequency': 6},
#   {'Date': datetime.date(2012, 1, 23), 'Frequency': 11},
#   {'Date': datetime.date(2012, 1, 24), 'Frequency': 16},
#   {'Date': datetime.date(2012, 1, 25), 'Frequency': 6},
#   {'Date': datetime.date(2012, 1, 26), 'Frequency': 9},
#   {'Date': datetime.date(2012, 1, 27), 'Frequency': 9},
#   {'Date': datetime.date(2012, 1, 28), 'Frequency': 14},
#   {'Date': datetime.date(2012, 1, 29), 'Frequency': 11},
#   {'Date': datetime.date(2012, 1, 30), 'Frequency': 11},
#   {'Date': datetime.date(2012, 1, 31), 'Frequency': 20}],
#  [{'Date': datetime.date(2013, 1, 1), 'Frequency': 11},
#   {'Date': datetime.date(2013, 1, 2), 'Frequency': 14},
#   {'Date': datetime.date(2013, 1, 3), 'Frequency': 12},
#   {'Date': datetime.date(2013, 1, 4), 'Frequency': 10},
#   {'Date': datetime.date(2013, 1, 5), 'Frequency': 6},
#   {'Date': datetime.date(2013, 1, 6), 'Frequency': 6},
#   {'Date': datetime.date(2013, 1, 7), 'Frequency': 15},
#   {'Date': datetime.date(2013, 1, 8), 'Frequency': 20},
#   {'Date': datetime.date(2013, 1, 9), 'Frequency': 13},
#   {'Date': datetime.date(2013, 1, 10), 'Frequency': 13},
#   {'Date': datetime.date(2013, 1, 11), 'Frequency': 14},
#   {'Date': datetime.date(2013, 1, 12), 'Frequency': 4},
#   {'Date': datetime.date(2013, 1, 13), 'Frequency': 8},
#   {'Date': datetime.date(2013, 1, 14), 'Frequency': 11},
#   {'Date': datetime.date(2013, 1, 15), 'Frequency': 9},
#   {'Date': datetime.date(2013, 1, 16), 'Frequency': 7},
#   {'Date': datetime.date(2013, 1, 17), 'Frequency': 10},
#   {'Date': datetime.date(2013, 1, 18), 'Frequency': 17},
#   {'Date': datetime.date(2013, 1, 19), 'Frequency': 5},
#   {'Date': datetime.date(2013, 1, 20), 'Frequency': 9},
#   {'Date': datetime.date(2013, 1, 21), 'Frequency': 4},
#   {'Date': datetime.date(2013, 1, 22), 'Frequency': 6},
#   {'Date': datetime.date(2013, 1, 23), 'Frequency': 5},
#   {'Date': datetime.date(2013, 1, 24), 'Frequency': 5},
#   {'Date': datetime.date(2013, 1, 25), 'Frequency': 3},
#   {'Date': datetime.date(2013, 1, 26), 'Frequency': 16},
#   {'Date': datetime.date(2013, 1, 27), 'Frequency': 3},
#   {'Date': datetime.date(2013, 1, 28), 'Frequency': 4},
#   {'Date': datetime.date(2013, 1, 29), 'Frequency': 3},
#   {'Date': datetime.date(2013, 1, 30), 'Frequency': 15},
#   {'Date': datetime.date(2013, 1, 31), 'Frequency': 5}],
#  [{'Date': datetime.date(2014, 1, 1), 'Frequency': 2},
#   {'Date': datetime.date(2014, 1, 2), 'Frequency': 6},
#   {'Date': datetime.date(2014, 1, 3), 'Frequency': 4},
#   {'Date': datetime.date(2014, 1, 4), 'Frequency': 2},
#   {'Date': datetime.date(2014, 1, 5), 'Frequency': 9},
#   {'Date': datetime.date(2014, 1, 6), 'Frequency': 5},
#   {'Date': datetime.date(2014, 1, 7), 'Frequency': 4},
#   {'Date': datetime.date(2014, 1, 8), 'Frequency': 4},
#   {'Date': datetime.date(2014, 1, 9), 'Frequency': 4},
#   {'Date': datetime.date(2014, 1, 10), 'Frequency': 7},
#   {'Date': datetime.date(2014, 1, 11), 'Frequency': 5},
#   {'Date': datetime.date(2014, 1, 12), 'Frequency': 3},
#   {'Date': datetime.date(2014, 1, 13), 'Frequency': 4},
#   {'Date': datetime.date(2014, 1, 14), 'Frequency': 15},
#   {'Date': datetime.date(2014, 1, 15), 'Frequency': 1},
#   {'Date': datetime.date(2014, 1, 16), 'Frequency': 3},
#   {'Date': datetime.date(2014, 1, 17), 'Frequency': 2},
#   {'Date': datetime.date(2014, 1, 18), 'Frequency': 1},
#   {'Date': datetime.date(2014, 1, 19), 'Frequency': 5},
#   {'Date': datetime.date(2014, 1, 20), 'Frequency': 5},
#   {'Date': datetime.date(2014, 1, 21), 'Frequency': 4},
#   {'Date': datetime.date(2014, 1, 22), 'Frequency': 20},
#   {'Date': datetime.date(2014, 1, 23), 'Frequency': 4},
#   {'Date': datetime.date(2014, 1, 24), 'Frequency': 14},
#   {'Date': datetime.date(2014, 1, 25), 'Frequency': 2},
#   {'Date': datetime.date(2014, 1, 26), 'Frequency': 4},
#   {'Date': datetime.date(2014, 1, 27), 'Frequency': 13},
#   {'Date': datetime.date(2014, 1, 28), 'Frequency': 7},
#   {'Date': datetime.date(2014, 1, 29), 'Frequency': 5},
#   {'Date': datetime.date(2014, 1, 30), 'Frequency': 3},
#   {'Date': datetime.date(2014, 1, 31), 'Frequency': 3}],
#  [{'Date': datetime.date(2015, 1, 1), 'Frequency': 2},
#   {'Date': datetime.date(2015, 1, 2), 'Frequency': 8},
#   {'Date': datetime.date(2015, 1, 3), 'Frequency': 3},
#   {'Date': datetime.date(2015, 1, 4), 'Frequency': 3},
#   {'Date': datetime.date(2015, 1, 5), 'Frequency': 7},
#   {'Date': datetime.date(2015, 1, 6), 'Frequency': 9},
#   {'Date': datetime.date(2015, 1, 7), 'Frequency': 3},
#   {'Date': datetime.date(2015, 1, 8), 'Frequency': 5},
#   {'Date': datetime.date(2015, 1, 9), 'Frequency': 5},
#   {'Date': datetime.date(2015, 1, 10), 'Frequency': 3},
#   {'Date': datetime.date(2015, 1, 11), 'Frequency': 4},
#   {'Date': datetime.date(2015, 1, 12), 'Frequency': 3},
#   {'Date': datetime.date(2015, 1, 13), 'Frequency': 3},
#   {'Date': datetime.date(2015, 1, 14), 'Frequency': 7},
#   {'Date': datetime.date(2015, 1, 15), 'Frequency': 15},
#   {'Date': datetime.date(2015, 1, 16), 'Frequency': 14},
#   {'Date': datetime.date(2015, 1, 17), 'Frequency': 2},
#   {'Date': datetime.date(2015, 1, 18), 'Frequency': 14},
#   {'Date': datetime.date(2015, 1, 19), 'Frequency': 6},
#   {'Date': datetime.date(2015, 1, 20), 'Frequency': 9},
#   {'Date': datetime.date(2015, 1, 21), 'Frequency': 13},
#   {'Date': datetime.date(2015, 1, 22), 'Frequency': 10},
#   {'Date': datetime.date(2015, 1, 23), 'Frequency': 4},
#   {'Date': datetime.date(2015, 1, 24), 'Frequency': 5},
#   {'Date': datetime.date(2015, 1, 25), 'Frequency': 3},
#   {'Date': datetime.date(2015, 1, 26), 'Frequency': 5},
#   {'Date': datetime.date(2015, 1, 27), 'Frequency': 3},
#   {'Date': datetime.date(2015, 1, 28), 'Frequency': 2},
#   {'Date': datetime.date(2015, 1, 29), 'Frequency': 5},
#   {'Date': datetime.date(2015, 1, 30), 'Frequency': 5},
#   {'Date': datetime.date(2015, 1, 31), 'Frequency': 5}],
#  [{'Date': datetime.date(2016, 1, 1), 'Frequency': 6},
#   {'Date': datetime.date(2016, 1, 2), 'Frequency': 5},
#   {'Date': datetime.date(2016, 1, 3), 'Frequency': 5},
#   {'Date': datetime.date(2016, 1, 4), 'Frequency': 5},
#   {'Date': datetime.date(2016, 1, 5), 'Frequency': 7},
#   {'Date': datetime.date(2016, 1, 6), 'Frequency': 4},
#   {'Date': datetime.date(2016, 1, 7), 'Frequency': 3},
#   {'Date': datetime.date(2016, 1, 8), 'Frequency': 2},
#   {'Date': datetime.date(2016, 1, 9), 'Frequency': 4},
#   {'Date': datetime.date(2016, 1, 10), 'Frequency': 3},
#   {'Date': datetime.date(2016, 1, 11), 'Frequency': 2},
#   {'Date': datetime.date(2016, 1, 12), 'Frequency': 1},
#   {'Date': datetime.date(2016, 1, 13), 'Frequency': 2},
#   {'Date': datetime.date(2016, 1, 14), 'Frequency': 3},
#   {'Date': datetime.date(2016, 1, 15), 'Frequency': 2},
#   {'Date': datetime.date(2016, 1, 16), 'Frequency': 2},
#   {'Date': datetime.date(2016, 1, 17), 'Frequency': 1},
#   {'Date': datetime.date(2016, 1, 18), 'Frequency': 2},
#   {'Date': datetime.date(2016, 1, 19), 'Frequency': 7},
#   {'Date': datetime.date(2016, 1, 20), 'Frequency': 2},
#   {'Date': datetime.date(2016, 1, 21), 'Frequency': 5},
#   {'Date': datetime.date(2016, 1, 22), 'Frequency': 6},
#   {'Date': datetime.date(2016, 1, 23), 'Frequency': 5},
#   {'Date': datetime.date(2016, 1, 24), 'Frequency': 36},
#   {'Date': datetime.date(2016, 1, 25), 'Frequency': 15},
#   {'Date': datetime.date(2016, 1, 26), 'Frequency': 3},
#   {'Date': datetime.date(2016, 1, 27), 'Frequency': 2},
#   {'Date': datetime.date(2016, 1, 28), 'Frequency': 4},
#   {'Date': datetime.date(2016, 1, 29), 'Frequency': 1},
#   {'Date': datetime.date(2016, 1, 30), 'Frequency': 26},
#   {'Date': datetime.date(2016, 1, 31), 'Frequency': 3}],
#  [{'Date': datetime.date(2017, 1, 1), 'Frequency': 3},
#   {'Date': datetime.date(2017, 1, 2), 'Frequency': 3},
#   {'Date': datetime.date(2017, 1, 3), 'Frequency': 1},
#   {'Date': datetime.date(2017, 1, 4), 'Frequency': 4},
#   {'Date': datetime.date(2017, 1, 5), 'Frequency': 0},
#   {'Date': datetime.date(2017, 1, 6), 'Frequency': 4},
#   {'Date': datetime.date(2017, 1, 7), 'Frequency': 2},
#   {'Date': datetime.date(2017, 1, 8), 'Frequency': 3},
#   {'Date': datetime.date(2017, 1, 9), 'Frequency': 6},
#   {'Date': datetime.date(2017, 1, 10), 'Frequency': 4},
#   {'Date': datetime.date(2017, 1, 11), 'Frequency': 3},
#   {'Date': datetime.date(2017, 1, 12), 'Frequency': 5},
#   {'Date': datetime.date(2017, 1, 13), 'Frequency': 6},
#   {'Date': datetime.date(2017, 1, 14), 'Frequency': 3},
#   {'Date': datetime.date(2017, 1, 15), 'Frequency': 2},
#   {'Date': datetime.date(2017, 1, 16), 'Frequency': 2},
#   {'Date': datetime.date(2017, 1, 17), 'Frequency': 5},
#   {'Date': datetime.date(2017, 1, 18), 'Frequency': 0},
#   {'Date': datetime.date(2017, 1, 19), 'Frequency': 5},
#   {'Date': datetime.date(2017, 1, 20), 'Frequency': 1},
#   {'Date': datetime.date(2017, 1, 21), 'Frequency': 2},
#   {'Date': datetime.date(2017, 1, 22), 'Frequency': 2},
#   {'Date': datetime.date(2017, 1, 23), 'Frequency': 1},
#   {'Date': datetime.date(2017, 1, 24), 'Frequency': 0},
#   {'Date': datetime.date(2017, 1, 25), 'Frequency': 5},
#   {'Date': datetime.date(2017, 1, 26), 'Frequency': 3},
#   {'Date': datetime.date(2017, 1, 27), 'Frequency': 3},
#   {'Date': datetime.date(2017, 1, 28), 'Frequency': 4},
#   {'Date': datetime.date(2017, 1, 29), 'Frequency': 5},
#   {'Date': datetime.date(2017, 1, 30), 'Frequency': 3},
#   {'Date': datetime.date(2017, 1, 31), 'Frequency': 2}],
#  [{'Date': datetime.date(2018, 1, 1), 'Frequency': 3},
#   {'Date': datetime.date(2018, 1, 2), 'Frequency': 3},
#   {'Date': datetime.date(2018, 1, 3), 'Frequency': 7},
#   {'Date': datetime.date(2018, 1, 4), 'Frequency': 6},
#   {'Date': datetime.date(2018, 1, 5), 'Frequency': 7},
#   {'Date': datetime.date(2018, 1, 6), 'Frequency': 4},
#   {'Date': datetime.date(2018, 1, 7), 'Frequency': 5},
#   {'Date': datetime.date(2018, 1, 8), 'Frequency': 6},
#   {'Date': datetime.date(2018, 1, 9), 'Frequency': 6},
#   {'Date': datetime.date(2018, 1, 10), 'Frequency': 3},
#   {'Date': datetime.date(2018, 1, 11), 'Frequency': 7},
#   {'Date': datetime.date(2018, 1, 12), 'Frequency': 11},
#   {'Date': datetime.date(2018, 1, 13), 'Frequency': 10},
#   {'Date': datetime.date(2018, 1, 14), 'Frequency': 3},
#   {'Date': datetime.date(2018, 1, 15), 'Frequency': 4},
#   {'Date': datetime.date(2018, 1, 16), 'Frequency': 3},
#   {'Date': datetime.date(2018, 1, 17), 'Frequency': 11},
#   {'Date': datetime.date(2018, 1, 18), 'Frequency': 6},
#   {'Date': datetime.date(2018, 1, 19), 'Frequency': 7},
#   {'Date': datetime.date(2018, 1, 20), 'Frequency': 7},
#   {'Date': datetime.date(2018, 1, 21), 'Frequency': 3},
#   {'Date': datetime.date(2018, 1, 22), 'Frequency': 12},
#   {'Date': datetime.date(2018, 1, 23), 'Frequency': 14},
#   {'Date': datetime.date(2018, 1, 24), 'Frequency': 16},
#   {'Date': datetime.date(2018, 1, 25), 'Frequency': 22},
#   {'Date': datetime.date(2018, 1, 26), 'Frequency': 16},
#   {'Date': datetime.date(2018, 1, 27), 'Frequency': 4},
#   {'Date': datetime.date(2018, 1, 28), 'Frequency': 7},
#   {'Date': datetime.date(2018, 1, 29), 'Frequency': 8},
#   {'Date': datetime.date(2018, 1, 30), 'Frequency': 8},
#   {'Date': datetime.date(2018, 1, 31), 'Frequency': 8}]]

# %%
pd.concat([pd.DataFrame(df_sg[0]),pd.DataFrame(df_sg[1]),pd.DataFrame(df_sg[2]),
          pd.DataFrame(df_sg[3]),pd.DataFrame(df_sg[4]),pd.DataFrame(df_sg[5]),pd.DataFrame(df_sg[6])]).to_csv('sg_twit.csv',encoding='utf-8',index=False)

# %%
sg_twit = pd.read_csv('sg_twit.csv',encoding='utf-8')
sg_twit
# Out:
#            Date  Frequency
# 0    2012-01-01          4
# 1    2012-01-02         21
# 2    2012-01-03         16
# 3    2012-01-04          5
# 4    2012-01-05         19
# 5    2012-01-06         17
# 6    2012-01-07         14
# 7    2012-01-08          7
# 8    2012-01-09         12
# 9    2012-01-10         14
# 10   2012-01-11         14
# 11   2012-01-12         12
# 12   2012-01-13         10
# 13   2012-01-14          5
# 14   2012-01-15          9
# 15   2012-01-16         11
# 16   2012-01-17         15
# 17   2012-01-18          7
# 18   2012-01-19         33
# 19   2012-01-20         11
# 20   2012-01-21          5
# 21   2012-01-22          6
# 22   2012-01-23         11
# 23   2012-01-24         16
# 24   2012-01-25          6
# 25   2012-01-26          9
# 26   2012-01-27          9
# 27   2012-01-28         14
# 28   2012-01-29         11
# 29   2012-01-30         11
# ..          ...        ...
# 187  2018-01-02          3
# 188  2018-01-03          7
# 189  2018-01-04          6
# 190  2018-01-05          7
# 191  2018-01-06          4
# 192  2018-01-07          5
# 193  2018-01-08          6
# 194  2018-01-09          6
# 195  2018-01-10          3
# 196  2018-01-11          7
# 197  2018-01-12         11
# 198  2018-01-13         10
# 199  2018-01-14          3
# 200  2018-01-15          4
# 201  2018-01-16          3
# 202  2018-01-17         11
# 203  2018-01-18          6
# 204  2018-01-19          7
# 205  2018-01-20          7
# 206  2018-01-21          3
# 207  2018-01-22         12
# 208  2018-01-23         14
# 209  2018-01-24         16
# 210  2018-01-25         22
# 211  2018-01-26         16
# 212  2018-01-27          4
# 213  2018-01-28          7
# 214  2018-01-29          8
# 215  2018-01-30          8
# 216  2018-01-31          8
#
# [217 rows x 2 columns]

# %%
sg_twit.loc[sg_twit['Date'].str.contains('2012'),'Year'] = '2012'
sg_twit.loc[sg_twit['Date'].str.contains('2013'),'Year'] = '2013'
sg_twit.loc[sg_twit['Date'].str.contains('2014'),'Year'] = '2014'
sg_twit.loc[sg_twit['Date'].str.contains('2015'),'Year'] = '2015'
sg_twit.loc[sg_twit['Date'].str.contains('2016'),'Year'] = '2016'
sg_twit.loc[sg_twit['Date'].str.contains('2017'),'Year'] = '2017'
sg_twit.loc[sg_twit['Date'].str.contains('2018'),'Year'] = '2018'

# %%
sg_twit
# Out:
#            Date  Frequency  Year
# 0    2012-01-01          4  2012
# 1    2012-01-02         21  2012
# 2    2012-01-03         16  2012
# 3    2012-01-04          5  2012
# 4    2012-01-05         19  2012
# 5    2012-01-06         17  2012
# 6    2012-01-07         14  2012
# 7    2012-01-08          7  2012
# 8    2012-01-09         12  2012
# 9    2012-01-10         14  2012
# 10   2012-01-11         14  2012
# 11   2012-01-12         12  2012
# 12   2012-01-13         10  2012
# 13   2012-01-14          5  2012
# 14   2012-01-15          9  2012
# 15   2012-01-16         11  2012
# 16   2012-01-17         15  2012
# 17   2012-01-18          7  2012
# 18   2012-01-19         33  2012
# 19   2012-01-20         11  2012
# 20   2012-01-21          5  2012
# 21   2012-01-22          6  2012
# 22   2012-01-23         11  2012
# 23   2012-01-24         16  2012
# 24   2012-01-25          6  2012
# 25   2012-01-26          9  2012
# 26   2012-01-27          9  2012
# 27   2012-01-28         14  2012
# 28   2012-01-29         11  2012
# 29   2012-01-30         11  2012
# ..          ...        ...   ...
# 187  2018-01-02          3  2018
# 188  2018-01-03          7  2018
# 189  2018-01-04          6  2018
# 190  2018-01-05          7  2018
# 191  2018-01-06          4  2018
# 192  2018-01-07          5  2018
# 193  2018-01-08          6  2018
# 194  2018-01-09          6  2018
# 195  2018-01-10          3  2018
# 196  2018-01-11          7  2018
# 197  2018-01-12         11  2018
# 198  2018-01-13         10  2018
# 199  2018-01-14          3  2018
# 200  2018-01-15          4  2018
# 201  2018-01-16          3  2018
# 202  2018-01-17         11  2018
# 203  2018-01-18          6  2018
# 204  2018-01-19          7  2018
# 205  2018-01-20          7  2018
# 206  2018-01-21          3  2018
# 207  2018-01-22         12  2018
# 208  2018-01-23         14  2018
# 209  2018-01-24         16  2018
# 210  2018-01-25         22  2018
# 211  2018-01-26         16  2018
# 212  2018-01-27          4  2018
# 213  2018-01-28          7  2018
# 214  2018-01-29          8  2018
# 215  2018-01-30          8  2018
# 216  2018-01-31          8  2018
#
# [217 rows x 3 columns]

# %%
df_sg_twit_sum = sg_twit.groupby('Year',as_index=False).sum()
df_sg_twit_sum['loc'] = '상계동'
df_sg_twit_sum
# Out:
#    Year  Frequency  loc
# 0  2012        374  상계동
# 1  2013        283  상계동
# 2  2014        170  상계동
# 3  2015        185  상계동
# 4  2016        174  상계동
# 5  2017         92  상계동
# 6  2018        237  상계동

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from plotnine import *
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="C:/Windows/Fonts/NanumGothic.ttf").get_name()
rc('font', family=font_name)
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 각 년도별 1월 트윗량 비교 그래프_연남vs상계

# %%
(ggplot(pd.concat([df_yn_twit_sum,df_sg_twit_sum]))
 + geom_line(aes('Year','Frequency',group='loc',color='loc'))
 + theme(text=element_text(family='NanumBarunGothic'), panel_background=element_rect(fill='white'))
 + scale_color_manual(values=("#76CEFE", "#FB427D"))
)
# Out:
# <ggplot: (10649732437)>
